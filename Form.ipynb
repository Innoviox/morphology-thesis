# %%
import spacy
import pandas as pd
# Out:
# 2023-09-08 13:31:08.342571: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
nlp = spacy.load("it_core_news_lg")

# %%
df = pd.read_excel("phonItalia 1.10 - word forms.xlsx")
df
# Out:
#          nLem  fqTot     fqTotL  fqQuo  fqPer  fqLib  dispT  dispQ  dispP  \
# 0        3560  50518  10.830085  23982  17679   8857   0.99   0.99   0.99
# 1        3560   5219   8.560061   2391   1948    880   0.99   0.99   0.98
# 2        3560   1544   7.342132    537    625    382   0.97   0.99   0.99
# 3        3560    272   5.605802    112     80     80   0.94   0.96   0.90
# 4        3562    234   5.455321    109    107     18   0.84   0.76   0.79
# ...       ...    ...        ...    ...    ...    ...    ...    ...    ...
# 119995  89330      5   1.609438      5      0      0   0.00   0.00   0.00
# 119996  89331      2   0.693147      2      0      0   0.00   0.00   0.00
# 119997  89332      1   0.000000      1      0      0   0.00   0.00   0.00
# 119998  89334      1   0.000000      0      1      0   0.00   0.00   0.00
# 119999  89335     12   2.484907      6      6      0   0.35   0.44   0.10
#
#         dispL  ...   OLD      OLDF  OLD_RelFreq   PLD      PLDF  PLD_RelFreq  \
# 0        0.99  ...  1.00  6.004370       1.8037  1.00  6.758153     1.602521
# 1        0.99  ...  1.00  6.004370     1.425639  1.00  6.758153     1.266627
# 2        0.97  ...  1.00  6.004370     1.222798  1.00  6.758153     1.086411
# 3        0.95  ...  1.00  6.004370      0.93362  1.00  6.758153     0.829487
# 4        0.79  ...  1.00  6.004370     0.908558  1.00  6.758153     0.807221
# ...       ...  ...   ...       ...          ...   ...       ...          ...
# 119995   0.00  ...  1.85  1.790223     0.899015  1.90  1.499083     1.073615
# 119996   0.00  ...  2.45  0.910700     0.761115  1.90  1.499083     0.462381
# 119997   0.00  ...  2.40  1.129599            0  2.35  1.007284            0
# 119998   0.00  ...  5.50  1.142923            0  5.70  0.947322            0
# 119999   0.00  ...  3.60  2.700312     0.920229  3.60  2.513429     0.988652
#
#          BG_Sum       BG_Mean  BP_Sum       BP_Mean
# 0             0      0.000000       0      0.000000
# 1             0      0.000000       0      0.000000
# 2             0      0.000000       0      0.000000
# 3             0      0.000000       0      0.000000
# 4             0      0.000000       0      0.000000
# ...         ...           ...     ...           ...
# 119995   196047  49011.750000  135076  33769.000000
# 119996   205893  41178.601563  135076  33769.000000
# 119997   509593  84932.164063  432115  72019.164063
# 119998  1068756  97159.632813  969221  88111.000000
# 119999   222726  31818.000000  176269  25181.285156
#
# [120000 rows x 58 columns]

# %%
df = df[['gramCat', 'lemma', 'word']] # only keep relevant columns
df
# Out:
#         gramCat         lemma          word
# 0             P             a             a
# 1       P IN P@             a             a
# 2       P IN B@             a             a
# 3       P IN C@             a             a
# 4             S             a             a
# ...         ...           ...           ...
# 119995        E         zurli         zurli
# 119996  E IN E@        zurli'        zurli'
# 119997        E       zurlini       zurlini
# 119998        G  zuzzurellone  zuzzurellone
# 119999        E      zuzzurro      zuzzurro
#
# [120000 rows x 3 columns]

# %%
import tqdm

df['morph'] = ''
df['pos'] = ''
for idx, row in tqdm.tqdm(df.iterrows()):
    try:
        tok = nlp(row['word'])[0]
        df.loc[idx, 'morph'] = tok.morph
        df.loc[idx, 'pos'] = tok.pos_
    except Exception as e:
        print(e, idx, row)
# Out:
# /var/folders/my/xjpgt3ss01991yghb67xgjs80000gn/T/ipykernel_10821/3411625173.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['morph'] = ''
# /var/folders/my/xjpgt3ss01991yghb67xgjs80000gn/T/ipykernel_10821/3411625173.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['pos'] = ''
# 0it [00:00, ?it/s]/var/folders/my/xjpgt3ss01991yghb67xgjs80000gn/T/ipykernel_10821/3411625173.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[idx, 'morph'] = tok.morph
# /var/folders/my/xjpgt3ss01991yghb67xgjs80000gn/T/ipykernel_10821/3411625173.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[idx, 'pos'] = tok.pos_
# 41364it [02:42, 254.98it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 6
#       4 df['pos'] = ''
#       5 for idx, row in tqdm.tqdm(df.iterrows()):
# ----> 6     tok = nlp(row['word'])[0]
#       7     df.loc[idx, 'morph'] = tok.morph
#       8     df.loc[idx, 'pos'] = tok.pos_
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/spacy/language.py:1030, in Language.__call__(self, text, disable, component_cfg)
#    1009 def __call__(
#    1010     self,
#    1011     text: Union[str, Doc],
#    (...)
#    1014     component_cfg: Optional[Dict[str, Dict[str, Any]]] = None,
#    1015 ) -> Doc:
#    1016     """Apply the pipeline to some text. The text can span multiple sentences,
#    1017     and can contain arbitrary whitespace. Alignment into the original string
#    1018     is preserved.
#    (...)
#    1028     DOCS: https://spacy.io/api/language#call
#    1029     """
# -> 1030     doc = self._ensure_doc(text)
#    1031     if component_cfg is None:
#    1032         component_cfg = {}
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/spacy/language.py:1124, in Language._ensure_doc(self, doc_like)
#    1122 if isinstance(doc_like, bytes):
#    1123     return Doc(self.vocab).from_bytes(doc_like)
# -> 1124 raise ValueError(Errors.E1041.format(type=type(doc_like)))
#
# ValueError: [E1041] Expected a string, Doc, or bytes as input, but got: <class 'bool'>

# %%
df['morph'].value_counts()
# Out:
#                                                                                                                97665
# (Gender=Masc, Number=Sing)                                                                                      3082
# (Gender=Fem, Number=Sing)                                                                                       3009
# (Gender=Masc, Number=Plur)                                                                                      2534
# (Gender=Fem, Number=Plur)                                                                                       1714
#                                                                                                                ...
# (Clitic=Yes, Gender=Fem, Number=Sing, Person=3, PronType=Prs, Tense=Past, VerbForm=Part)                           1
# (Clitic=Yes, Number=Sing, Person=1, PronType=Prs, VerbForm=Ger)                                                    1
# (Clitic=Yes, Gender=Fem, Mood=Imp, Number=Plur, Person=1, Person=3, PronType=Prs, Tense=Pres, VerbForm=Fin)        1
# (Gender=Masc, Number=Sing, PronType=Int)                                                                           1
# (Gender=Fem, NumType=Ord, Number=Plur)                                                                             1
# Name: morph, Length: 126, dtype: int64
